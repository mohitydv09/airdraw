# %%
# %%capture
# !pip install ultralytics

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import os

# %%
from ultralytics import YOLO

# %%
yolov8_model = YOLO('/Users/saturn/Documents/Spring 24/Computer Vision/cv_final_project/airdraw/best.pt')

# %%
image_head = cv2.imread('header.jpeg')

# %%
results = yolov8_model('/Users/saturn/Documents/Spring 24/Computer Vision/cv_final_project/airdraw/trial_image.jpg')  # Inference
# Out:
# image 1/1 /Users/saturn/Documents/Spring 24/Computer Vision/cv_final_project/airdraw/trial_image.jpg: 320x448 1 one, 68.1ms
# Speed: 5.3ms preprocess, 68.1ms inference, 1210.6ms postprocess per image at shape (1, 3, 320, 448)

# %%
print(boxes.xywh)
# Out:
# tensor([[630.9280, 528.1929, 307.8962, 492.2458]])

# %%
cap = cv2.VideoCapture(0)

cap.set(3,480)
cap.set(4,480)

# c= (0,255,0)
# list_ = [(x,200,c) for x in range(200)]
#          #(120,120), (150,150)
        #  ]

while cap.isOpened():
  success, image = cap.read()

  ## Send the image to model.
  results = yolov8_model(image)
  for result in results:
    boxes = result.boxes.xyxy
    for box in boxes:
      image = cv2.rectangle(image, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (0,255,0), 2)

  # image = cv2.rectangle(image, (int(boxes[0][0]), int(boxes[0][1])), (int(boxes[0][2]), int(boxes[0][3])), (0,255,0), 2)

  # image[0:115,0:1280] = image_head[0:115,0:1280]
  # image =  cv2.flip(image, 1)

  ## Send the image to model to get the output.

  # for point in list_:
  #   x,y, color = point
  #   image = cv2.circle(image, (x,y), 10, color, -1)

  cv2.imshow("Image",image)
  # cv2.imshow('Image', image)
  if cv2.waitKey(10) & 0xFF == ord('q'):
      break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 0: 352x448 (no detections), 105.2ms
# Speed: 2.1ms preprocess, 105.2ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 448)
#
# 0: 352x448 (no detections), 236.4ms
# Speed: 23.8ms preprocess, 236.4ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 448)
#
# 0: 352x448 (no detections), 118.8ms
# Speed: 2.8ms preprocess, 118.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 448)
#
# 0: 352x448 (no detections), 82.0ms
# Speed: 2.8ms preprocess, 82.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 448)
#
# 0: 352x448 (no detections), 87.9ms
# Speed: 2.3ms preprocess, 87.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 448)
#
# 0: 352x448 (no detections), 92.2ms
# Speed: 2.5ms preprocess, 92.2ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 448)
#
# 0: 352x448 (no detections), 93.0ms
# Speed: 2.9ms preprocess, 93.0ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 448)
#
# ...

# %%
import mediapipe as mp
import cv2
import matplotlib.pyplot as plt
import numpy as np
import uuid           # Random Name generation
import os

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
cap = cv2.VideoCapture(0)

with mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5, max_num_hands = 2) as hands: 
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame,1)
        
        
        # Detection
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        image.flags.writeable = False
        results = hands.process(image)
        image.flags.writeable = True

        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        if results.multi_hand_landmarks:
            for num, hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS)

        cv2.imshow("Hand tracking ", image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)   # This is added to get close the window on macs.

# %%
import smal lyolo

# %%
## small
